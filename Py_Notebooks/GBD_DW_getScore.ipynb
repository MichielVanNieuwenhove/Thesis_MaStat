# %%
# Libs
import pandas as pd
import random
from sentence_transformers import SentenceTransformer, util
import numpy as np
import torch

# %%
# General
SEED = 42
random.seed(SEED)

# %% [markdown]
# # Loading Data

# %%
df_dw = pd.read_feather("../Data/DW/df_dw_filtered.feather")
print(df_dw.head())
# Out:
#                                          Sequela Name  \
# 0   HIV/AIDS -  Drug-susceptible Tuberculosis with...
# 12                     Symptomatic HIV without anemia
# 13                                AIDS without anemia
# 14                           Early HIV without anemia
# 24  HIV/AIDS with antiretroviral treatment without...
#
#                                     Health State Name  \
# 0                          Tuberculosis, HIV infected
# 12                   HIV cases, symptomatic, pre-AIDS
# 13            AIDS cases, not receiving ARV treatment
# 14  Generic uncomplicated disease: anxiety about d...
# 24            HIV/AIDS cases, receiving ARV treatment
#
#                          Health State Lay Description      Mean     Lower  \
# 0   has a persistent cough and fever, shortness of...  0.408459  0.273579
# 12  has weight loss, fatigue, and frequent infecti...  0.274479  0.184359
# 13  has severe weight loss, weakness, fatigue, cou...  0.581590  0.405544
# 14  has a disease diagnosis that causes some worry...  0.012441  0.006195
# 24  has occasional fevers and infections. the pers...  0.078017  0.052124
#
#        Upper                                     Split Symptoms
# 0   0.549465  [has a persistent cough, fever, shortness of b...
# 12  0.377096    [has weight loss, fatigue, frequent infections]
# 13  0.742606  [has severe weight loss, weakness, fatigue, co...
# 14  0.022709  [has a disease diagnosis that causes some worr...
# 24  0.111067  [has occasional fevers, infections, the person...

# %%
df_dta = pd.read_feather('../Data/Cleaned/df_dta_cleaned.feather')
print(df_dta.head())
# Out:
#    ID_dta        fDISEASE fDIMENSION fDOMAIN          fCRITERION fINDICATOR  \
# 0       1  Crohns Disease   Patients  Health  Impact on autonomy   Mobility
# 1       2  Crohns Disease   Patients  Health  Impact on autonomy   Mobility
# 2       3  Crohns Disease   Patients  Health  Impact on autonomy   Mobility
# 3       4  Crohns Disease   Patients  Health  Impact on autonomy  Self-care
# 4       5  Crohns Disease   Patients  Health  Impact on autonomy  Self-care
#
#   fDISEASE_SUBTYPE fDISEASE_PROXY fCOUNTRY_PROXY    YEAR  ... VALUE_char  SD  \
# 0              NaN            NaN            NaN  2023.0  ...       None NaN
# 1              NaN            NaN            NaN  2023.0  ...       None NaN
# 2              NaN            NaN            NaN  2023.0  ...       None NaN
# 3              NaN            NaN            NaN  2023.0  ...       None NaN
# 4              NaN            NaN            NaN  2023.0  ...       None NaN
#
#   LOWER CI UPPER CI       SOURCE KEY_POINT  QUOTES  META_1  META_2 COMMENTS
# 0      NaN      NaN  NEED survey      None    None    None    None     None
# 1      NaN      NaN  NEED survey      None    None    None    None     None
# 2      NaN      NaN  NEED survey      None    None    None    None     None
# 3      NaN      NaN  NEED survey      None    None    None    None     None
# 4      NaN      NaN  NEED survey      None    None    None    None     None
#
# [5 rows x 25 columns]

# %% [markdown]
# # Transforming Data

# %%
df_dta['fINDICATOR'] = df_dta['fINDICATOR'].replace(
    'Experienced burden of psychological symptoms related to the health issue',
    'Experienced burden of psychological symptoms'
)

df_dta_disabilities = df_dta[
    df_dta['fINDICATOR'].isin([
        'Experienced burden of physical symptoms',
        'Experienced burden of psychological symptoms'
    ])
]
# Out:
# C:\Users\Gebruiker\AppData\Local\Temp\ipykernel_22944\1106502321.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df_dta['fINDICATOR'] = df_dta['fINDICATOR'].replace(

# %%
print(len(df_dta_disabilities['CATEGORIES']))
# Out:
# 50

# %%
print(df_dta_disabilities['CATEGORIES'])
# Out:
# 21                                             Anal pain
# 22                     Blood loss during bowel movements
# 23                                          Constipation
# 24                             Continuous abdominal pain
# 25                                                Cramps
# 26                                             Diarrhoea
# 27                               Difficult wound healing
# 28                    Dry, painful or itchy skin or rash
# 29                         Elevated temperature or fever
# 30                                 Fatigue or exhaustion
# 31                                              Headache
# 32                            Joint pain or inflammation
# 33                                        Lack of energy
# 34                                      Loss of appetite
# 35                                    Nausea or vomiting
# 36         Pain in the mouth due to, for example, ulcers
# 37                                 Urgency or stool urge
# 38                           Vision problems or eye pain
# 39                                           Weight gain
# 40                                           Weight loss
# 47                               Anger or aggressiveness
# 48                           Difficulty in concentrating
# 49                                       Fear or anxiety
# 50                   Feeling down, depressed, or sadness
# 51     Feelings of restlessness, nervousness or irrit...
# 52                                       Libido problems
# 53                                           Mood swings
# 54                                                Stress
# 97                                Breathing difficulties
# 98                                            Chest pain
# 99                                 Concentration problem
# 100                            Difficulty/loss of memory
# 101                                              Fatigue
# 102                                             Headache
# 103                                           Joint pain
# 104                                       Loss of energy
# 105                                        Lost of smell
# 106                                        Lost of taste
# 107                             Muscle pain and weakness
# 114                                         Fear/anxiety
# 115                                             Insomnia
# 140                                Fatigue or exhaustion
# 141                                        Painful wound
# 142                        Swollen or painful lymph node
# 149                                      Fear or anxiety
# 150                                    Feeling abandoned
# 151                      Feeling down, depressed, or sad
# 152                                             Insomnia
# 153                         Irritability or restlessness
# 154                                               Stress
# Name: CATEGORIES, dtype: object

# %% [markdown]
# # Disability Matching

# %%
model = SentenceTransformer('all-mpnet-base-v2')

# %% [markdown]
# ## Testing

# %%
input_text = "fever"

# Your disability labels (simplified example, expand with your full list)
disability_labels = [
    "Elevated temperature or fever"
]

# Encode
input_embedding = model.encode(input_text, convert_to_tensor=True)
label_embeddings = model.encode(disability_labels, convert_to_tensor=True)

# Compute cosine similarity
cosine_scores = util.cos_sim(input_embedding, label_embeddings)[0]

# Display top matches
results = sorted(zip(disability_labels, cosine_scores.tolist()), key=lambda x: x[1], reverse=True)

print("Top matches:")
for label, score in results[:5]:
    print(f"{label}: {score:.3f}")
# Out:
# Top matches:
# Elevated temperature or fever: 0.660

# %%
categories = df_dta_disabilities['CATEGORIES'].unique()
texts = df_dw['Health State Lay Description'].tolist()
text_embeddings = model.encode(texts, convert_to_tensor=True)

# Loop through each category
for category in categories:
    # Encode the category
    category_embedding = model.encode(category, convert_to_tensor=True)
    
    # Compute cosine similarities
    cosine_scores = util.cos_sim(category_embedding, text_embeddings)[0]
    best_idx = cosine_scores.argmax().item()
    
    print(f"\nCategory: {category}")
    print(f"Best Match: {texts[best_idx]}")
    print(f"Similarity Score: {cosine_scores[best_idx].item():.4f}")
# Out:
# Category: Anal pain
# Best Match: has cramping pain and a bloated feeling in the belly.
# Similarity Score: 0.3867
#
# Category: Blood loss during bowel movements
# Best Match: has diarrhea three or more times a day, with painful cramps in the belly and feeling thirsty
# Similarity Score: 0.4177
#
# Category: Constipation
# Best Match: cannot control urinating.
# Similarity Score: 0.5527
#
# Category: Continuous abdominal pain
# Best Match: has cramping pain and a bloated feeling in the belly.
# Similarity Score: 0.5483
#
# Category: Cramps
# Best Match: has cramping pains in the legs after walking a medium distance. the pain goes away after a short rest.
# Similarity Score: 0.3840
#
# Category: Diarrhoea
# Best Match: vomits blood and feels nauseous.
# Similarity Score: 0.6610
#
# Category: Difficult wound healing
# Best Match: has swollen legs with hard and thick skin, which causes difficulty in moving around.
# Similarity Score: 0.3464
#
# Category: Dry, painful or itchy skin or rash
# Best Match: has a blistering skin rash that causes pain, with some burning and itching.
# Similarity Score: 0.6787
#
# Category: Elevated temperature or fever
# Best Match: has a low fever and mild discomfort , but no difficulty with daily activities.
# Similarity Score: 0.6159
#
# Category: Fatigue or exhaustion
# Best Match: is short of breath and feels tired when at rest. the person avoids any physical activity, for fear of worsening the breathing problems.
# Similarity Score: 0.4060
#
# Category: Headache
# Best Match: has daily headaches, felt as dull pain and often lasting all day, with poor sleep, nausea and fatigue. the person takes medicine for the headaches, which provides little relief but is needed to avoid having worse symptoms.
# Similarity Score: 0.5200
#
# Category: Joint pain or inflammation
# Best Match: has moderate pain and stiffness in the arms and hands, which causes difficulty lifting, carrying, and holding things, and trouble sleeping because of the pain.
# Similarity Score: 0.5234
#
# Category: Lack of energy
# Best Match: has low energy and feels cold.
# Similarity Score: 0.6942
#
# Category: Loss of appetite
# Best Match: feels an overwhelming need to starve and exercises excessively to lose weight. the person is very thin, weak and anxious.
# Similarity Score: 0.5055
#
# Category: Nausea or vomiting
# Best Match: vomits blood and feels nauseous.
# Similarity Score: 0.5616
#
# Category: Pain in the mouth due to, for example, ulcers
# Best Match: has a toothache, which causes some difficulty in eating.
# Similarity Score: 0.6083
#
# Category: Urgency or stool urge
# Best Match: feels the urge to urinate frequently, but when passing urine it comes out slowly and sometimes is painful.
# Similarity Score: 0.4750
#
# Category: Vision problems or eye pain
# Best Match: has some difficulty with distance vision, for example reading signs, but no other problems with eyesight.
# Similarity Score: 0.5347
#
# Category: Weight gain
# Best Match: is extremely skinny and has no energy.
# Similarity Score: 0.3782
#
# Category: Weight loss
# Best Match: has uncontrolled overeating followed by guilt, starving, and vomiting to lose weight.
# Similarity Score: 0.4342
#
# Category: Anger or aggressiveness
# Best Match: is hyperactive, hears and believes things that are not real, and engages in impulsive and aggressive behavior that endanger the person and others.
# Similarity Score: 0.4326
#
# Category: Difficulty in concentrating
# Best Match: has some trouble remembering recent events, and finds it hard to concentrate and make decisions and plans.
# Similarity Score: 0.5255
#
# Category: Fear or anxiety
# Best Match: feels nervous, has palpitations, sweats a lot and has difficulty sleeping.
# Similarity Score: 0.4925
#
# Category: Feeling down, depressed, or sadness
# Best Match: feels persistent sadness and has lost interest in usual activities. the person sometimes sleeps badly, feels tired, or has trouble concentrating but still manages to function in daily life with extra effort.
# Similarity Score: 0.5635
#
# Category: Feelings of restlessness, nervousness or irritability
# Best Match: feels mildly anxious and worried, which makes it slightly difficult to concentrate, remember things, and sleep. the person tires easily but is able to perform daily activities.
# Similarity Score: 0.7014
#
# Category: Libido problems
# Best Match: has difficulty in obtaining or maintaining an erection.
# Similarity Score: 0.4868
#
# Category: Mood swings
# Best Match: feels persistent sadness and has lost interest in usual activities. the person sometimes sleeps badly, feels tired, or has trouble concentrating but still manages to function in daily life with extra effort.
# Similarity Score: 0.5153
#
# Category: Stress
# Best Match: feels anxious and worried, which makes it difficult to concentrate, remember things, and sleep. the person tires easily and finds it difficult to perform daily activities.
# Similarity Score: 0.4298
#
# Category: Breathing difficulties
# Best Match: is short of breath and feels tired when at rest. the person avoids any physical activity, for fear of worsening the breathing problems.
# Similarity Score: 0.6569
#
# Category: Chest pain
# Best Match: has chest pain that occurs with strenuous physical activity, such as running or lifting heavy objects. after a brief rest, the pain goes away.
# Similarity Score: 0.7078
#
# Category: Concentration problem
# Best Match: loses small amounts of urine without meaning to when coughing, sneezing, laughing or during physical exercise.
# Similarity Score: 0.2477
#
# Category: Difficulty/loss of memory
# Best Match: has some trouble remembering recent events, and finds it hard to concentrate and make decisions and plans.
# Similarity Score: 0.5432
#
# Category: Fatigue
# Best Match: has low energy and feels cold.
# Similarity Score: 0.4537
#
# Category: Joint pain
# Best Match: has moderate pain and stiffness in the arms and hands, which causes difficulty lifting, carrying, and holding things, and trouble sleeping because of the pain.
# Similarity Score: 0.5193
#
# Category: Loss of energy
# Best Match: is extremely skinny and has no energy.
# Similarity Score: 0.3284
#
# Category: Lost of smell
# Best Match: loses small amounts of urine without meaning to when coughing, sneezing, laughing or during physical exercise.
# Similarity Score: 0.4060
#
# Category: Lost of taste
# Best Match: has uncontrolled overeating followed by guilt, starving, and vomiting to lose weight.
# Similarity Score: 0.2984
#
# Category: Muscle pain and weakness
# Best Match: feels moderate fatigue, weakness, and shortness of breath after exercise, making daily activities more difficult.
# Similarity Score: 0.5184
#
# Category: Fear/anxiety
# Best Match: feels nervous, has palpitations, sweats a lot and has difficulty sleeping.
# Similarity Score: 0.5223
#
# Category: Insomnia
# Best Match: feels mildly anxious and worried, which makes it slightly difficult to concentrate, remember things, and sleep. the person tires easily but is able to perform daily activities.
# Similarity Score: 0.3772
#
# Category: Painful wound
# Best Match: has a slight, visible physical deformity that is sometimes sore or itchy. others notice the deformity, which causes some worry and discomfort.
# Similarity Score: 0.4543
#
# Category: Swollen or painful lymph node
# Best Match: has swelling and tenderness in the testicles and pain during urination.
# Similarity Score: 0.4353
#
# Category: Feeling abandoned
# Best Match: feels persistent sadness and has lost interest in usual activities. the person sometimes sleeps badly, feels tired, or has trouble concentrating but still manages to function in daily life with extra effort.
# Similarity Score: 0.2790
#
# Category: Feeling down, depressed, or sad
# Best Match: feels persistent sadness and has lost interest in usual activities. the person sometimes sleeps badly, feels tired, or has trouble concentrating but still manages to function in daily life with extra effort.
# Similarity Score: 0.5247
#
# Category: Irritability or restlessness
# Best Match: feels mildly anxious and worried, which makes it slightly difficult to concentrate, remember things, and sleep. the person tires easily but is able to perform daily activities.
# Similarity Score: 0.7010

# %%
split_symptoms_all = []
original_indices = []
for idx, symptoms_list in enumerate(df_dw['Split Symptoms']):
    for symptom in symptoms_list:
        split_symptoms_all.append(symptom)
        original_indices.append(idx)

# Encode all split symptoms once
split_symptom_embeddings = model.encode(split_symptoms_all, convert_to_tensor=True)

categories = df_dta_disabilities['CATEGORIES'].unique()
texts = df_dw['Health State Lay Description'].tolist()

for category in categories:
    # Encode the category
    category_embedding = model.encode(category, convert_to_tensor=True)
    
    # Compute cosine similarities between category and all split symptoms
    cosine_scores = util.cos_sim(category_embedding, split_symptom_embeddings)[0]
    best_idx = cosine_scores.argmax().item()
    
    matched_symptom = split_symptoms_all[best_idx]
    original_idx = original_indices[best_idx]
    original_text = texts[original_idx]
    similarity = cosine_scores[best_idx].item()
    
    print(f"\n🔹 Category: {category}")
    print(f"   Best Matching Symptom: {matched_symptom}")
    print(f"   From Original Description: {original_text}")
    print(f"   Similarity Score: {similarity:.4f}")
# Out:
# 🔹 Category: Anal pain
#    Best Matching Symptom: pain
#    From Original Description: has a high fever and pain, and feels very weak, which causes great difficulty with daily activities.
#    Similarity Score: 0.6221
#
# 🔹 Category: Blood loss during bowel movements
#    Best Matching Symptom: loss of urine or bowel control
#    From Original Description: has sudden seizures one or more times each month, with violent muscle contractions and stiffness, loss of consciousness, and loss of urine or bowel control. between seizures the person has memory loss and difficulty concentrating.
#    Similarity Score: 0.6445
#
# 🔹 Category: Constipation
#    Best Matching Symptom: bowel control
#    From Original Description: is paralyzed from the waist down, cannot feel or move the legs and has difficulties with urine and bowel control. the person uses a wheelchair to move around.
#    Similarity Score: 0.6101
#
# 🔹 Category: Continuous abdominal pain
#    Best Matching Symptom: has cramping abdominal pain
#    From Original Description: has cramping abdominal pain, has diarrhea several times a day, and feels very tired for two months every year. when the person does not have symptoms, there is anxiety about them returning.
#    Similarity Score: 0.6964
#
# 🔹 Category: Cramps
#    Best Matching Symptom: cramps
#    From Original Description: is tired and has itching, cramps, headache, joint pains and shortness of breath. the person needs intensive medical care every other day lasting about half a day.
#    Similarity Score: 1.0000
#
# 🔹 Category: Diarrhoea
#    Best Matching Symptom: diarrhea
#    From Original Description: has severe weight loss, weakness, fatigue, cough and fever, and frequent infections, skin rashes and diarrhea.
#    Similarity Score: 0.9578
#
# 🔹 Category: Difficult wound healing
#    Best Matching Symptom: recovering cause great difficulty in daily activities
#    From Original Description: drinks a lot, gets drunk almost every week and has great difficulty controlling the urge to drink. drinking and recovering cause great difficulty in daily activities, sleep loss, and fatigue.
#    Similarity Score: 0.4529
#
# 🔹 Category: Dry, painful or itchy skin or rash
#    Best Matching Symptom: skin rashes
#    From Original Description: has severe weight loss, weakness, fatigue, cough and fever, and frequent infections, skin rashes and diarrhea.
#    Similarity Score: 0.7530
#
# 🔹 Category: Elevated temperature or fever
#    Best Matching Symptom: has a high fever
#    From Original Description: has a high fever and pain, and feels very weak, which causes great difficulty with daily activities.
#    Similarity Score: 0.7220
#
# 🔹 Category: Fatigue or exhaustion
#    Best Matching Symptom: fatigue
#    From Original Description: has a persistent cough and fever, shortness of breath, night sweats, weakness and fatigue and severe weight loss.
#    Similarity Score: 0.7264
#
# 🔹 Category: Headache
#    Best Matching Symptom: headache
#    From Original Description: is tired and has itching, cramps, headache, joint pains and shortness of breath. the person needs intensive medical care every other day lasting about half a day.
#    Similarity Score: 1.0000
#
# 🔹 Category: Joint pain or inflammation
#    Best Matching Symptom: joint pains
#    From Original Description: is tired and has itching, cramps, headache, joint pains and shortness of breath. the person needs intensive medical care every other day lasting about half a day.
#    Similarity Score: 0.8136
#
# 🔹 Category: Lack of energy
#    Best Matching Symptom: has low energy
#    From Original Description: has low energy and feels cold.
#    Similarity Score: 0.7235
#
# 🔹 Category: Loss of appetite
#    Best Matching Symptom: loss of appetite
#    From Original Description: has a swollen belly and swollen legs. the person feels weakness, fatigue and loss of appetite.
#    Similarity Score: 1.0000
#
# 🔹 Category: Nausea or vomiting
#    Best Matching Symptom: nausea
#    From Original Description: has pain, nausea, fatigue, weight loss and high anxiety.
#    Similarity Score: 0.7802
#
# 🔹 Category: Pain in the mouth due to, for example, ulcers
#    Best Matching Symptom: sometimes bleeds from the gums
#    From Original Description: easily bruises and sometimes bleeds from the gums and nose; feels weak and has some difficulty with daily activities.
#    Similarity Score: 0.5922
#
# 🔹 Category: Urgency or stool urge
#    Best Matching Symptom: loss of urine or bowel control
#    From Original Description: has sudden seizures one or more times each month, with violent muscle contractions and stiffness, loss of consciousness, and loss of urine or bowel control. between seizures the person has memory loss and difficulty concentrating.
#    Similarity Score: 0.5871
#
# 🔹 Category: Vision problems or eye pain
#    Best Matching Symptom: but no other problems with eyesight
#    From Original Description: has some difficulty with distance vision, for example reading signs, but no other problems with eyesight.
#    Similarity Score: 0.6810
#
# 🔹 Category: Weight gain
#    Best Matching Symptom: severe weight loss
#    From Original Description: has a persistent cough and fever, shortness of breath, night sweats, weakness and fatigue and severe weight loss.
#    Similarity Score: 0.6106
#
# 🔹 Category: Weight loss
#    Best Matching Symptom: weight loss
#    From Original Description: has pain, nausea, fatigue, weight loss and high anxiety.
#    Similarity Score: 1.0000
#
# 🔹 Category: Anger or aggressiveness
#    Best Matching Symptom: irritability
#    From Original Description: has mild mood swings, irritability and some difficulty with daily activities.
#    Similarity Score: 0.6465
#
# 🔹 Category: Difficulty in concentrating
#    Best Matching Symptom: difficulty concentrating
#    From Original Description: has sudden seizures one or more times each month, with violent muscle contractions and stiffness, loss of consciousness, and loss of urine or bowel control. between seizures the person has memory loss and difficulty concentrating.
#    Similarity Score: 0.9802
#
# 🔹 Category: Fear or anxiety
#    Best Matching Symptom: anxiety
#    From Original Description: is completely blind, which causes great difficulty in some daily activities, worry and anxiety, and great difficulty going outside the home without assistance.
#    Similarity Score: 0.8220
#
# 🔹 Category: Feeling down, depressed, or sadness
#    Best Matching Symptom: depression or loneliness
#    From Original Description: cannot hear at all in any situation, including even the loudest sounds, and cannot communicate verbally or use a phone. difficulties with communicating and relating to others often cause worry, depression or loneliness.
#    Similarity Score: 0.6931
#
# 🔹 Category: Feelings of restlessness, nervousness or irritability
#    Best Matching Symptom: feels slightly tired
#    From Original Description: feels slightly tired and weak at times, but this does not interfere with normal daily activities.
#    Similarity Score: 0.6142
#
# 🔹 Category: Libido problems
#    Best Matching Symptom: has difficulty in obtaining or maintaining an erection
#    From Original Description: has difficulty in obtaining or maintaining an erection.
#    Similarity Score: 0.6170
#
# 🔹 Category: Mood swings
#    Best Matching Symptom: mood swings
#    From Original Description: uses stimulants (drugs) and has difficulty controlling the habit. the person sometimes has depression, hallucinations and mood swings, and has difficulty in daily activities.
#    Similarity Score: 1.0000
#
# 🔹 Category: Stress
#    Best Matching Symptom: anxiety
#    From Original Description: is completely blind, which causes great difficulty in some daily activities, worry and anxiety, and great difficulty going outside the home without assistance.
#    Similarity Score: 0.7897
#
# 🔹 Category: Breathing difficulties
#    Best Matching Symptom: shortness of breath all the time
#    From Original Description: has cough, wheezing and shortness of breath all the time. the person has great difficulty walking even short distances or climbing any stairs, feels tired when at rest, and is anxious.
#    Similarity Score: 0.7912
#
# 🔹 Category: Chest pain
#    Best Matching Symptom: has chest pain that occurs with strenuous physical activity
#    From Original Description: has chest pain that occurs with strenuous physical activity, such as running or lifting heavy objects. after a brief rest, the pain goes away.
#    Similarity Score: 0.7338
#
# 🔹 Category: Concentration problem
#    Best Matching Symptom: concentrating
#    From Original Description: has a visible physical deformity that causes others to stare and comment. as a result, the person is worried and has trouble sleeping and concentrating.
#    Similarity Score: 0.3722
#
# 🔹 Category: Difficulty/loss of memory
#    Best Matching Symptom: has memory problems
#    From Original Description: has memory problems and confusion, feels disoriented, at times hears voices that are not real, and needs help with some daily activities.
#    Similarity Score: 0.6968
#
# 🔹 Category: Fatigue
#    Best Matching Symptom: fatigue
#    From Original Description: has a persistent cough and fever, shortness of breath, night sweats, weakness and fatigue and severe weight loss.
#    Similarity Score: 1.0000
#
# 🔹 Category: Joint pain
#    Best Matching Symptom: joint pains
#    From Original Description: is tired and has itching, cramps, headache, joint pains and shortness of breath. the person needs intensive medical care every other day lasting about half a day.
#    Similarity Score: 0.9350
#
# 🔹 Category: Loss of energy
#    Best Matching Symptom: has no energy
#    From Original Description: is extremely skinny and has no energy.
#    Similarity Score: 0.6503
#
# 🔹 Category: Lost of smell
#    Best Matching Symptom: short of breath
#    From Original Description: feels very weak, tired and short of breath, and has problems with activities that require physical effort or deep concentration.
#    Similarity Score: 0.5631
#
# 🔹 Category: Lost of taste
#    Best Matching Symptom: has lost some enjoyment in life
#    From Original Description: has constant back and leg pain, which causes difficulty dressing, sitting, standing, walking, and lifting things. the person sleeps poorly, is worried, and has lost some enjoyment in life.
#    Similarity Score: 0.5958
#
# 🔹 Category: Muscle pain and weakness
#    Best Matching Symptom: muscle weakness
#    From Original Description: has pain, tingling and numbness in the arms, legs, hands and feet. the person sometimes gets cramps and muscle weakness.
#    Similarity Score: 0.8399
#
# 🔹 Category: Fear/anxiety
#    Best Matching Symptom: anxiety
#    From Original Description: uses marijuana daily and has difficulty controlling the habit. the person sometimes has mood swings, anxiety and hallucinations, and has some difficulty in daily activities.
#    Similarity Score: 0.8510
#
# 🔹 Category: Insomnia
#    Best Matching Symptom: sleep loss
#    From Original Description: drinks a lot, gets drunk almost every week and has great difficulty controlling the urge to drink. drinking and recovering cause great difficulty in daily activities, sleep loss, and fatigue.
#    Similarity Score: 0.7027
#
# 🔹 Category: Painful wound
#    Best Matching Symptom: pain
#    From Original Description: has a high fever and pain, and feels very weak, which causes great difficulty with daily activities.
#    Similarity Score: 0.6141
#
# 🔹 Category: Swollen or painful lymph node
#    Best Matching Symptom: swelling in the leg
#    From Original Description: has severe pain and swelling in the leg, making it very difficult to get up and down, stand, walk, lift, and carry heavy things. the person has trouble sleeping because of the pain.
#    Similarity Score: 0.5751
#
# 🔹 Category: Feeling abandoned
#    Best Matching Symptom: loneliness
#    From Original Description: is unable to hear and understand another person talking, even in a quiet place, is unable to take part in a phone conversation, and has great difficulty hearing anything in any other situation. difficulties with communicating and relating to othersoften cause worry, depression, and loneliness.
#    Similarity Score: 0.6133
#
# 🔹 Category: Feeling down, depressed, or sad
#    Best Matching Symptom: depression or loneliness
#    From Original Description: cannot hear at all in any situation, including even the loudest sounds, and cannot communicate verbally or use a phone. difficulties with communicating and relating to others often cause worry, depression or loneliness.
#    Similarity Score: 0.6851
#
# 🔹 Category: Irritability or restlessness
#    Best Matching Symptom: irritability
#    From Original Description: has mild mood swings, irritability and some difficulty with daily activities.
#    Similarity Score: 0.6815

# %% [markdown]
# ## Map all disabilities to rows in the GBD data

# %% [markdown]
# ### Based on split symptoms

# %%
SIMILARITY_TRESHOLD = 0.7

# %%
matched_ids_per_row = []
matched_cat_per_row = []

categories = df_dta_disabilities['CATEGORIES'].tolist()
category_ids = df_dta_disabilities['ID_dta'].tolist()
category_embeddings = model.encode(categories, convert_to_tensor=True)

for idx, symptoms_list in enumerate(df_dw['Split Symptoms']):
    if len(symptoms_list) == 0:
        matched_ids_per_row.append([])
        continue
    
    symptom_embeddings = model.encode(symptoms_list, convert_to_tensor=True)
    matched_ids = set()
    cosine_scores = util.cos_sim(category_embeddings, symptom_embeddings)
    
    for cat_idx, cat_id in enumerate(category_ids):
        if (cosine_scores[cat_idx] >= SIMILARITY_TRESHOLD).any().item():
            matched_ids.add(cat_id)
    
    matched_ids_per_row.append(list(matched_ids))
    matched_cat_per_row.append([id_to_category[cat_id] for cat_id in matched_ids])

df_dw['Matching Category IDs'] = matched_ids_per_row
df_dw['Matching Categories'] = matched_cat_per_row

# %%
# Transform the outcome data
df_dw_filtered = df_dw[df_dw['Matching Category IDs'].apply(lambda x: len(x) > 0)].copy()

len(df_dw_filtered)
# Out:
# 36

# %%
pd.set_option('display.max_colwidth', None)
print(df_dw_filtered[['Health State Lay Description', 'Mean', 'Matching Categories']].head())
pd.set_option('display.max_colwidth', 50)
# Out:
#                                                                                                   Health State Lay Description  \
# 0            has a persistent cough and fever, shortness of breath, night sweats, weakness and fatigue and severe weight loss.
# 12                                                                          has weight loss, fatigue, and frequent infections.
# 13             has severe weight loss, weakness, fatigue, cough and fever, and frequent infections, skin rashes and diarrhea.
# 74                        has a high fever and pain, and feels very weak, which causes great difficulty with daily activities.
# 91  has diarrhea three or more times a day with severe belly cramps. the person is very thirsty and feels nauseous and tired.
#
#         Mean  \
# 0   0.408459
# 12  0.274479
# 13  0.581590
# 74  0.133412
# 91  0.247096
#
#                                                                                                        Matching Categories
# 0                          [Breathing difficulties, Fatigue, Fatigue or exhaustion, Stress, Stress, Fatigue or exhaustion]
# 12                                    [Fatigue, Weight loss, Fatigue or exhaustion, Stress, Stress, Fatigue or exhaustion]
# 13  [Fatigue, Stress, Fatigue or exhaustion, Stress, Diarrhoea, Dry, painful or itchy skin or rash, Fatigue or exhaustion]
# 74                                                                                         [Elevated temperature or fever]
# 91                                                                                                               [Fatigue]

# %% [markdown]
# # Testing Mapping Accuracy

# %%
i = random.randint(0, len(df_dw_filtered) - 1)

row = df_dw_filtered.iloc[i]
description = row['Health State Lay Description']
matched_ids = row['Matching Category IDs']
    
# Get category names for matched IDs
matched_categories = df_dta_disabilities.loc[
    df_dta_disabilities['ID_dta'].isin(matched_ids), 'CATEGORIES'].tolist()
    
print(f"\nRow {i}:")
print(f"Description: {description}")
print(f"Matched Categories: {matched_categories}")
# Out:
# Row 17:
# Description: has chest pain that occurs with minimal physical activity, such as walking only a short distance. after a brief rest, the pain goes away. the person avoids most physical activities because of the pain.
# Matched Categories: ['Chest pain']

# %% [markdown]
# # Map to fDISEASE

# %%
rows = []
disease_to_ids = df_dta_disabilities.groupby('fDISEASE')['ID_dta'].apply(set).to_dict()

for disease, disease_ids in disease_to_ids.items():
    for idx, row in df_dw_filtered.iterrows():
        matched_ids = row['Matching Category IDs']
        if not matched_ids:
            continue
        
        filtered_ids = [id_ for id_ in matched_ids if id_ in disease_ids]
        
        if filtered_ids:
            rows.append({
                'Disease': disease,
                'Health State Lay Description': row['Health State Lay Description'],
                'Matching Category IDs': filtered_ids,
                'Matching Category IDs': filtered_ids,
                'Mean' : row['Mean'],
                'Lower' : row['Lower'],
                'Upper' : row['Upper']
            })

df_disease_matches = pd.DataFrame(rows)
# Out:
# C:\Users\Gebruiker\AppData\Local\Temp\ipykernel_22944\258976354.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disease_to_ids = df_dta_disabilities.groupby('fDISEASE')['ID_dta'].apply(set).to_dict()

# %%
# Only keep the lowest scores

df_exploded = df_disease_matches.explode('Matching Category IDs')

df_deduplicated = (
    df_exploded
    .sort_values('Mean')  # So lowest Mean comes first
    .drop_duplicates(subset=['Disease', 'Matching Category IDs'], keep='first')
)

df_final = (
    df_deduplicated
    .groupby(['Disease', 'Health State Lay Description'])
    .agg({
        'Mean': 'min',
        'Matching Category IDs': lambda x: list(set(x))
    })
    .reset_index()
)

# %%
df_final.to_excel('../Data/DW/df_disease_matches.xlsx', index=False)
print(df_final)
# Out:
#                Disease                       Health State Lay Description  \
# 0       Crohns Disease  has a high fever and pain, and feels very weak...
# 1       Crohns Disease  has a swollen belly and swollen legs. the pers...
# 2       Crohns Disease  has daily headaches, felt as dull pain and oft...
# 3       Crohns Disease                     has low energy and feels cold.
# 4       Crohns Disease  has mild mood swings, irritability and some di...
# 5       Crohns Disease  has severe weight loss, weakness, fatigue, cou...
# 6       Crohns Disease  has weight loss, fatigue, and frequent infecti...
# 7       Crohns Disease  is completely blind, which causes great diffic...
# 8       Crohns Disease  is hyperactive and has difficulty concentratin...
# 9       Crohns Disease  is tired and has itching, cramps, headache, jo...
# 10      Crohns Disease     is very tired and irritable and has diarrhea.
# 11      Crohns Disease  tires easily, has nausea, reduced appetite and...
# 12          Long COVID  drinks a lot, gets drunk almost every week and...
# 13          Long COVID  feels very weak, tired and short of breath, an...
# 14          Long COVID  has chest pain that occurs with strenuous phys...
# 15          Long COVID  has pain, tingling and numbness in the arms, l...
# 16          Long COVID  has wheezing, cough and shortness of breath mo...
# 17          Long COVID  is completely blind, which causes great diffic...
# 18          Long COVID  is tired and has itching, cramps, headache, jo...
# 19  Malignant melanoma  drinks a lot, gets drunk almost every week and...
# 20  Malignant melanoma  has a swollen belly and swollen legs. the pers...
# 21  Malignant melanoma  is completely blind, which causes great diffic...
#
#         Mean Matching Category IDs
# 0   0.133412                  [30]
# 1   0.178203              [55, 31]
# 2   0.222926                  [36]
# 3   0.018609                  [34]
# 4   0.031955                  [54]
# 5   0.581590                  [29]
# 6   0.274479                  [41]
# 7   0.187365                  [50]
# 8   0.044530                  [49]
# 9   0.570897          [32, 33, 26]
# 10  0.050987                  [27]
# 11  0.104477                  [35]
# 12  0.373245                 [116]
# 13  0.148766                 [102]
# 14  0.033192                  [99]
# 15  0.133190                 [108]
# 16  0.132692                  [98]
# 17  0.187365                 [115]
# 18  0.570897            [104, 103]
# 19  0.373245                 [153]
# 20  0.178203            [155, 141]
# 21  0.187365                 [150]

# %%
len(df_final)
# Out:
# 22

# %% [markdown]
# # Calculate Score per disease
